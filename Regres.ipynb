# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
pollution=pd.read_csv("AirQualityUCI.csv")
pollution
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     3/10/2004  18:00:00     2.6       1360.0     150.0      11.9
# 1     3/10/2004  19:00:00     2.0       1292.0     112.0       9.4
# 2     3/10/2004  20:00:00     2.2       1402.0      88.0       9.0
# 3     3/10/2004  21:00:00     2.2       1376.0      80.0       9.2
# 4     3/10/2004  22:00:00     1.6       1272.0      51.0       6.5
# ...         ...       ...     ...          ...       ...       ...
# 9466        NaN       NaN     NaN          NaN       NaN       NaN
# 9467        NaN       NaN     NaN          NaN       NaN       NaN
# 9468        NaN       NaN     NaN          NaN       NaN       NaN
# 9469        NaN       NaN     NaN          NaN       NaN       NaN
# 9470        NaN       NaN     NaN          NaN       NaN       NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
pollution.head(10)
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0  3/10/2004  18:00:00     2.6       1360.0     150.0      11.9
# 1  3/10/2004  19:00:00     2.0       1292.0     112.0       9.4
# 2  3/10/2004  20:00:00     2.2       1402.0      88.0       9.0
# 3  3/10/2004  21:00:00     2.2       1376.0      80.0       9.2
# 4  3/10/2004  22:00:00     1.6       1272.0      51.0       6.5
# 5  3/10/2004  23:00:00     1.2       1197.0      38.0       4.7
# 6  3/11/2004   0:00:00     1.2       1185.0      31.0       3.6
# 7  3/11/2004   1:00:00     1.0       1136.0      31.0       3.3
# 8  3/11/2004   2:00:00     0.9       1094.0      24.0       2.3
# 9  3/11/2004   3:00:00     0.6       1010.0      19.0       1.7
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         1046.0    166.0        1056.0    113.0        1692.0       1268.0
# 1          955.0    103.0        1174.0     92.0        1559.0        972.0
# ...

# %%
pollution.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9471 entries, 0 to 9470
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           9357 non-null   object
#  1   Time           9357 non-null   object
#  2   CO(GT)         9357 non-null   float64
#  3   PT08.S1(CO)    9357 non-null   float64
#  4   NMHC(GT)       9357 non-null   float64
#  5   C6H6(GT)       9357 non-null   float64
#  6   PT08.S2(NMHC)  9357 non-null   float64
#  7   NOx(GT)        9357 non-null   float64
#  8   PT08.S3(NOx)   9357 non-null   float64
#  9   NO2(GT)        9357 non-null   float64
#  10  PT08.S4(NO2)   9357 non-null   float64
#  11  PT08.S5(O3)    9357 non-null   float64
#  12  T              9357 non-null   float64
#  13  RH             9357 non-null   float64
#  14  AH             9357 non-null   float64
#  15  Unnamed: 15    0 non-null      float64
#  16  Unnamed: 16    0 non-null      float64
# ...

# %%
pollution.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %%
pollution.isnull().sum()
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %%
pollution.isnull().sum()
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %%
pollution.shape
# Out:
# (9471, 17)

# %%
pollution.shape
# Out:
# (9471, 17)

# %%
pollution=pollution.fillna(pollution.mean(numeric_only=True))
pollution
# Out:
#            Date      Time     CO(GT)  PT08.S1(CO)    NMHC(GT)   C6H6(GT)  \
# 0     3/10/2004  18:00:00   2.600000  1360.000000  150.000000  11.900000
# 1     3/10/2004  19:00:00   2.000000  1292.000000  112.000000   9.400000
# 2     3/10/2004  20:00:00   2.200000  1402.000000   88.000000   9.000000
# 3     3/10/2004  21:00:00   2.200000  1376.000000   80.000000   9.200000
# 4     3/10/2004  22:00:00   1.600000  1272.000000   51.000000   6.500000
# ...         ...       ...        ...          ...         ...        ...
# 9466        NaN       NaN -34.207524  1048.990061 -159.090093   1.865683
# 9467        NaN       NaN -34.207524  1048.990061 -159.090093   1.865683
# 9468        NaN       NaN -34.207524  1048.990061 -159.090093   1.865683
# 9469        NaN       NaN -34.207524  1048.990061 -159.090093   1.865683
# 9470        NaN       NaN -34.207524  1048.990061 -159.090093   1.865683
#
#       PT08.S2(NMHC)     NOx(GT)  PT08.S3(NOx)     NO2(GT)  PT08.S4(NO2)  \
# ...

# %%
pollution.isnull().sum()
# Out:
# Date              114
# Time              114
# CO(GT)              0
# PT08.S1(CO)         0
# NMHC(GT)            0
# C6H6(GT)            0
# PT08.S2(NMHC)       0
# NOx(GT)             0
# PT08.S3(NOx)        0
# NO2(GT)             0
# PT08.S4(NO2)        0
# PT08.S5(O3)         0
# T                   0
# RH                  0
# AH                  0
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %%
pollution['Date'] = pollution['Date'].fillna(method='ffill')
pollution['Time'] = pollution['Time'].fillna(method='ffill')
pollution
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7996\3880842552.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollution['Date'] = pollution['Date'].fillna(method='ffill')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7996\3880842552.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pollution['Time'] = pollution['Time'].fillna(method='ffill')
#            Date      Time     CO(GT)  PT08.S1(CO)    NMHC(GT)   C6H6(GT)  \
# 0     3/10/2004  18:00:00   2.600000  1360.000000  150.000000  11.900000
# 1     3/10/2004  19:00:00   2.000000  1292.000000  112.000000   9.400000
# 2     3/10/2004  20:00:00   2.200000  1402.000000   88.000000   9.000000
# 3     3/10/2004  21:00:00   2.200000  1376.000000   80.000000   9.200000
# 4     3/10/2004  22:00:00   1.600000  1272.000000   51.000000   6.500000
# ...

# %%
pollution = pollution.drop(columns=['Unnamed: 15', 'Unnamed: 16'])
pollution
# Out:
#            Date      Time     CO(GT)  PT08.S1(CO)    NMHC(GT)   C6H6(GT)  \
# 0     3/10/2004  18:00:00   2.600000  1360.000000  150.000000  11.900000
# 1     3/10/2004  19:00:00   2.000000  1292.000000  112.000000   9.400000
# 2     3/10/2004  20:00:00   2.200000  1402.000000   88.000000   9.000000
# 3     3/10/2004  21:00:00   2.200000  1376.000000   80.000000   9.200000
# 4     3/10/2004  22:00:00   1.600000  1272.000000   51.000000   6.500000
# ...         ...       ...        ...          ...         ...        ...
# 9466   4/4/2005  14:00:00 -34.207524  1048.990061 -159.090093   1.865683
# 9467   4/4/2005  14:00:00 -34.207524  1048.990061 -159.090093   1.865683
# 9468   4/4/2005  14:00:00 -34.207524  1048.990061 -159.090093   1.865683
# 9469   4/4/2005  14:00:00 -34.207524  1048.990061 -159.090093   1.865683
# 9470   4/4/2005  14:00:00 -34.207524  1048.990061 -159.090093   1.865683
#
#       PT08.S2(NMHC)     NOx(GT)  PT08.S3(NOx)     NO2(GT)  PT08.S4(NO2)  \
# ...

# %%
pollution.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
pollution.duplicated().sum()
# Out:
# np.int64(113)

# %%
pollution=pollution.drop_duplicates()

# %%
X=pollution.drop(columns=['CO(GT)','Date','Time'])
y=pollution['CO(GT)']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# lr = LinearRegression()
# lr.fit(X_train, y_train)

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# y_pred = rf.predict(X_test)
# print("MAE:", mean_absolute_error(y_test, y_pred))
# print("RMSE:", mean_squared_error(y_test, y_pred))
# print("R2 Score:", r2_score(y_test, y_pred))

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

models = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(alpha=1.0),
    "Lasso Regression": Lasso(alpha=0.01),
    "Decision Tree": DecisionTreeRegressor(random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42),
    "SVR": Pipeline([
        ("scaler", StandardScaler()),
        ("svr", SVR(kernel="rbf"))
    ])
}

results = []

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    results.append({
        "Model": name,
        "MAE": mean_absolute_error(y_test, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_test, y_pred)),
        "R2": r2_score(y_test, y_pred)
    })

results_df = pd.DataFrame(results)
results_df.sort_values(by='R2',ascending=False)
results_df
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.047e+07, tolerance: 3.972e+03
#   model = cd_fast.enet_coordinate_descent(
#                Model        MAE       RMSE        R2
# 0  Linear Regression  34.550045  54.828052  0.494456
# 1   Ridge Regression  34.550045  54.828052  0.494456
# 2   Lasso Regression  34.539817  54.829406  0.494432
# 3      Decision Tree  23.059978  67.547584  0.232687
# 4  Gradient Boosting  27.303780  50.632939  0.568859
# 5                SVR  21.358040  54.953147  0.492147

# %%
plt.figure()
plt.barh(results_df['Model'],results_df['R2'])
plt.title("Model Comparison using R2 score")
plt.xlabel("R2 Score")
plt.show()

# %%
final= GradientBoostingRegressor(random_state=42)
final.fit(X,y)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
test_data = {
    'PT08.S1(CO)': 1120,
    'NMHC(GT)': 160,
    'C6H6(GT)': 5.4,
    'PT08.S2(NMHC)': 920,
    'NOx(GT)': 135,
    'PT08.S3(NOx)': 610,
    'NO2(GT)': 75,
    'PT08.S4(NO2)': 132 ,
    'PT08.S5(O3)': 88 ,
    'T': 26,
    'RH': 58,
    'AH': 1.15
}

# %%
prediction = pd.DataFrame([test_data])
prediction
# Out:
#    PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  \
# 0         1120       160       5.4            920      135           610
#
#    NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)   T  RH    AH
# 0       75           132           88  26  58  1.15

# %%
future_prediction=final.predict(prediction)
future_prediction
# Out:
# array([0.27415784])

# %%
co_value = future_prediction[0] 

if co_value < 2.0:
    result = "Low Air Pollution (Good Air Quality)"
elif co_value <= 5.0:
    result = "Moderate Air Pollution"
else:
    result = "High Air Pollution (Unhealthy)"

print("Predicted CO(GT):", round(co_value, 2), "mg/m³")
print("Air Pollution Result:", result)
# Out:
# Predicted CO(GT): 0.27 mg/m³
# Air Pollution Result: Low Air Pollution (Good Air Quality)
